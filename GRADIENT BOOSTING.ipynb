# %% [markdown]
# <a href="https://colab.research.google.com/github/kurmapu767/kurmapu767/blob/main/GRADIENT%20BOOSTING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#GRADIENT BOOSTING






from google.colab import files
upload= files.upload()
# Out:
#      <input type="file" id="files-2f102c2c-2b87-4a28-9e9e-62c6cb53dddd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f102c2c-2b87-4a28-9e9e-62c6cb53dddd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Boston.csv")
df.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
y=df["medv"]
x=df.iloc[:,1:-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr= GradientBoostingRegressor(learning_rate=0.01,n_estimators=300)
from sklearn.metrics import mean_squared_error

# %%
gbr.fit(x_train,y_train)
y_pred_train=gbr.predict(x_train)
y_pred_test=gbr.predict(x_test)
mse1=np.sqrt(mean_squared_error(y_train,y_pred_train))
mse2=np.sqrt(mean_squared_error(y_test,y_pred_test))
print("mse1:",mse1)
print("mse2:",mse2)
# Out:
# mse1: 2.2708435242926077
# mse2: 3.3529459984071863

# %%
print("gradient boosting  difference of train and test:",mse1-mse2)
# Out:
# gradient boosting  difference of train and test: -1.0821024741145786
